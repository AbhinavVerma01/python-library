# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Seaborn Library:
# is a statisticl data visualization library.
# offers users a high-level interface to make visualizations.they are ready mode datasets

# %%
import seaborn as sns

# %%
df=sns.load_dataset("diamonds")

# %%
df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %% [markdown]
# Examining DataSet

# %%
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
df.tail()
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64

# %%
df.shape
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  category
#  2   color    53940 non-null  category
#  3   clarity  53940 non-null  category
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53940 non-null  int64
#  7   x        53940 non-null  float64
#  8   y        53940 non-null  float64
#  9   z        53940 non-null  float64
# dtypes: category(3), float64(6), int64(1)
# memory usage: 3.0 MB

# %% [markdown]
# Aggregation() function:
# MEAN, MIN,COUNT,MEDIAN,SUM,MAX,STD,VAR,STD

# %%
df=sns.load_dataset("diamonds")
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
df.mean(numeric_only=True)
# Out:
# carat       0.797940
# depth      61.749405
# table      57.457184
# price    3932.799722
# x           5.731157
# y           5.734526
# z           3.538734
# dtype: float64

# %%
df["depth"].mean()
# Out:
# np.float64(61.749404894327036)

# %%
df.median(numeric_only=True)
# Out:
# carat       0.70
# depth      61.80
# table      57.00
# price    2401.00
# x           5.70
# y           5.71
# z           3.53
# dtype: float64

# %%
df["cut"].count()
# Out:
# np.int64(53940)

# %%
df["price"].min()
df["price"].max()
# Out:
# np.int64(18823)

# %%
sns.displot(df["price"]);

# %%
sns.displot(df["table"]);

# %%
df.std( numeric_only=True)
# Out:
# carat       0.474011
# depth       1.432621
# table       2.234491
# price    3989.439738
# x           1.121761
# y           1.142135
# z           0.705699
# dtype: float64

# %%
df["price"].var()
# Out:
# np.float64(15915629.42430145)

# %%
df["price"].sum()
# Out:
# np.int64(212135217)

# %%
df.describe()
df.describe().T
# Out:
#          count         mean          std    min     25%      50%      75%  \
# carat  53940.0     0.797940     0.474011    0.2    0.40     0.70     1.04
# depth  53940.0    61.749405     1.432621   43.0   61.00    61.80    62.50
# table  53940.0    57.457184     2.234491   43.0   56.00    57.00    59.00
# price  53940.0  3932.799722  3989.439738  326.0  950.00  2401.00  5324.25
# x      53940.0     5.731157     1.121761    0.0    4.71     5.70     6.54
# y      53940.0     5.734526     1.142135    0.0    4.72     5.71     6.54
# z      53940.0     3.538734     0.705699    0.0    2.91     3.53     4.04
#
#             max
# carat      5.01
# depth     79.00
# table     95.00
# price  18823.00
# x         10.74
# y         58.90
# z         31.80

# %% [markdown]
# Examining Dataset

# %%
df=sns.load_dataset("planets")
df
# Out:
#                method  number  orbital_period   mass  distance  year
# 0     Radial Velocity       1      269.300000   7.10     77.40  2006
# 1     Radial Velocity       1      874.774000   2.21     56.95  2008
# 2     Radial Velocity       1      763.000000   2.60     19.84  2011
# 3     Radial Velocity       1      326.030000  19.40    110.62  2007
# 4     Radial Velocity       1      516.220000  10.50    119.47  2009
# ...               ...     ...             ...    ...       ...   ...
# 1030          Transit       1        3.941507    NaN    172.00  2006
# 1031          Transit       1        2.615864    NaN    148.00  2007
# 1032          Transit       1        3.191524    NaN    174.00  2007
# 1033          Transit       1        4.125083    NaN    293.00  2008
# 1034          Transit       1        4.187757    NaN    260.00  2008
#
# [1035 rows x 6 columns]

# %%
df.head()
# Out:
#             method  number  orbital_period   mass  distance  year
# 0  Radial Velocity       1         269.300   7.10     77.40  2006
# 1  Radial Velocity       1         874.774   2.21     56.95  2008
# 2  Radial Velocity       1         763.000   2.60     19.84  2011
# 3  Radial Velocity       1         326.030  19.40    110.62  2007
# 4  Radial Velocity       1         516.220  10.50    119.47  2009

# %%
df.mean(numeric_only=True)
# Out:
# number               1.785507
# orbital_period    2002.917596
# mass                 2.638161
# distance           264.069282
# year              2009.070531
# dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1035 entries, 0 to 1034
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   method          1035 non-null   object
#  1   number          1035 non-null   int64
#  2   orbital_period  992 non-null    float64
#  3   mass            513 non-null    float64
#  4   distance        808 non-null    float64
#  5   year            1035 non-null   int64
# dtypes: float64(3), int64(2), object(1)
# memory usage: 48.6+ KB

# %%
df["method"]=pd.Categorical(df["method"])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1035 entries, 0 to 1034
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   method          1035 non-null   category
#  1   number          1035 non-null   int64
#  2   orbital_period  992 non-null    float64
#  3   mass            513 non-null    float64
#  4   distance        808 non-null    float64
#  5   year            1035 non-null   int64
# dtypes: category(1), float64(3), int64(2)
# memory usage: 41.9 KB

# %% [markdown]
# Guroping And Aggragtion funtion

# %%
df.head()
# Out:
#             method  number  orbital_period   mass  distance  year
# 0  Radial Velocity       1         269.300   7.10     77.40  2006
# 1  Radial Velocity       1         874.774   2.21     56.95  2008
# 2  Radial Velocity       1         763.000   2.60     19.84  2011
# 3  Radial Velocity       1         326.030  19.40    110.62  2007
# 4  Radial Velocity       1         516.220  10.50    119.47  2009

# %%
df["method"].value_counts()
# Out:
# method
# Radial Velocity                  553
# Transit                          397
# Imaging                           38
# Microlensing                      23
# Eclipse Timing Variations          9
# Pulsar Timing                      5
# Transit Timing Variations          4
# Orbital Brightness Modulation      3
# Astrometry                         2
# Pulsation Timing Variations        1
# Name: count, dtype: int64

# %%
df["method"].unique()
# Out:
# ['Radial Velocity', 'Imaging', 'Eclipse Timing Variations', 'Transit', 'Astrometry', 'Transit Timing Variations', 'Orbital Brightness Modulation', 'Microlensing', 'Pulsar Timing', 'Pulsation Timing Variations']
# Categories (10, object): ['Astrometry', 'Eclipse Timing Variations', 'Imaging', 'Microlensing', ..., 'Pulsation Timing Variations', 'Radial Velocity', 'Transit', 'Transit Timing Variations']

# %%
df["method"].nunique()
# Out:
# 10

# %%
df["distance"].value_counts(dropna=False)
# Out:
# distance
# NaN       227
# 780.00      7
# 6.80        6
# 39.39       6
# 303.00      6
#          ...
# 19.28       1
# 3.22        1
# 152.30      1
# 228.00      1
# 492.00      1
# Name: count, Length: 553, dtype: int64

# %%
df.distance.isnull().sum()
# Out:
# np.int64(227)

# %%
df.groupby("method")
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_16072\82256956.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby("method")

# %%
df.groupby("method").mean()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_16072\105516377.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby("method").mean()
#                                  number  orbital_period      mass  \
# method
# Astrometry                     1.000000      631.180000       NaN
# Eclipse Timing Variations      1.666667     4751.644444  5.125000
# Imaging                        1.315789   118247.737500       NaN
# Microlensing                   1.173913     3153.571429       NaN
# Orbital Brightness Modulation  1.666667        0.709307       NaN
# Pulsar Timing                  2.200000     7343.021201       NaN
# Pulsation Timing Variations    1.000000     1170.000000       NaN
# Radial Velocity                1.721519      823.354680  2.630699
# ...

# %%
df.groupby("method")[["distance"]]
df.groupby("method")[["distance"]].mean()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_16072\4067480207.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby("method")[["distance"]]
# C:\Users\Dell\AppData\Local\Temp\ipykernel_16072\4067480207.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby("method")[["distance"]].mean()
#                                   distance
# method
# Astrometry                       17.875000
# Eclipse Timing Variations       315.360000
# Imaging                          67.715937
# Microlensing                   4144.000000
# Orbital Brightness Modulation  1180.000000
# ...

# %%
df.groupby("year")[["number"]].sum()
# Out:
#       number
# year
# 1989       1
# 1992       6
# 1994       3
# 1995       1
# 1996      15
# 1997       1
# 1998      11
# 1999      24
# 2000      27
# 2001      15
# 2002      46
# 2003      35
# 2004      41
# 2005      64
# 2006      43
# 2007      65
# 2008     120
# 2009     131
# 2010     193
# 2011     354
# 2012     258
# 2013     277
# 2014     117

# %%
df[df["year"]==1992]
# Out:
#             method  number  orbital_period  mass  distance  year
# 941  Pulsar Timing       3         25.2620   NaN       NaN  1992
# 942  Pulsar Timing       3         66.5419   NaN       NaN  1992

# %% [markdown]
# Adavange Aggraregation Function

# %%
df=pd.DataFrame({
    "Group":["x","y","z","x","y","z"],
    "val1":[2,5,10,20,42,32],
    "val2":[23,54,19,209,424,324]
})
df
# Out:
#   Group  val1  val2
# 0     x     2    23
# 1     y     5    54
# 2     z    10    19
# 3     x    20   209
# 4     y    42   424
# 5     z    32   324

# %%
df.groupby("Group").mean()
# Out:
#        val1   val2
# Group
# x      11.0  116.0
# y      23.5  239.0
# z      21.0  171.5

# %%
df.groupby("Group").aggregate(["mean",np.median,min,"sum"])
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_16072\1155513169.py:1: FutureWarning: The provided callable <function median at 0x000002F418DCF740> is currently using SeriesGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   df.groupby("Group").aggregate(["mean",np.median,min,"sum"])
# C:\Users\Dell\AppData\Local\Temp\ipykernel_16072\1155513169.py:1: FutureWarning: The provided callable <built-in function min> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   df.groupby("Group").aggregate(["mean",np.median,min,"sum"])
#        val1                  val2
#        mean median min sum   mean median min  sum
# Group
# x      11.0   11.0   2  22  116.0  116.0  23  232
# y      23.5   23.5   5  47  239.0  239.0  54  478
# z      21.0   21.0  10  42  171.5  171.5  19  343

# %%
df.groupby("Group").aggregate({"val1":"mean","val2":"median"})
# Out:
#        val1   val2
# Group
# x      11.0  116.0
# y      23.5  239.0
# z      21.0  171.5

# %% [markdown]
# Fillter()

# %%
df
# Out:
#   Group  val1  val2
# 0     x     2    23
# 1     y     5    54
# 2     z    10    19
# 3     x    20   209
# 4     y    42   424
# 5     z    32   324

# %%
df.groupby("Group").mean()
# Out:
#        val1   val2
# Group
# x      11.0  116.0
# y      23.5  239.0
# z      21.0  171.5

# %%
def example_fun(x):
    return x["val2"].mean() < 200

# %%
df.groupby("Group").filter(example_fun)
# Out:
#   Group  val1  val2
# 0     x     2    23
# 2     z    10    19
# 3     x    20   209
# 5     z    32   324

# %%
df.groupby("Group").filter(lambda x:x["val2"].std()>105)
# Out:
#   Group  val1  val2
# 0     x     2    23
# 1     y     5    54
# 2     z    10    19
# 3     x    20   209
# 4     y    42   424
# 5     z    32   324

# %%
df = pd.read_csv('hlo.csv')
df
# Out:
#          Date    Product  Sales  Price    Location
# 0  01-01-2024  Product A    200     50    New York
# 1  02-01-2024  Product B    150     30  California
# 2  03-01-2024  Product A    180     50       Texas
# 3  04-01-2024  Product C    220     80    New York
# 4  05-01-2024  Product B    130     30  California
# 5  06-01-2024  Product A    250     50       Texas
# 6  07-01-2024  Product C    300     80    New York
# 7  08-01-2024  Product B    170     30  California
# 8  09-01-2024  Product A    200     50       Texas
# 9  10-01-2024  Product C    220     80    New York

# %% [markdown]
# Transform()

# %%
df=pd.DataFrame({
    "Group":["x","y","z","x","y","z"],
    "val1":[2,5,10,20,42,32],
    "val2":[23,54,19,209,424,324]
})
df
# Out:
#   Group  val1  val2
# 0     x     2    23
# 1     y     5    54
# 2     z    10    19
# 3     x    20   209
# 4     y    42   424
# 5     z    32   324

# %% [markdown]
# x'=x-min(x)/max(x)-min(x)

# %%
df_new=df.loc[:,"val1":"val2"]
df_new
# Out:
#    val1  val2
# 0     2    23
# 1     5    54
# 2    10    19
# 3    20   209
# 4    42   424
# 5    32   324

# %%
def normalize(x):
    return (x-x.min())/(x.max()-x.min())

# %%
df_new.transform(normalize)
# Out:
#     val1      val2
# 0  0.000  0.009877
# 1  0.075  0.086420
# 2  0.200  0.000000
# 3  0.450  0.469136
# 4  1.000  1.000000
# 5  0.750  0.753086

# %%
df_new.loc[1,"val2"]
# Out:
# np.int64(54)

# %%
df_new.transform(lambda a:np.sin(a))
# Out:
#        val1      val2
# 0  0.909297 -0.846220
# 1 -0.958924 -0.558789
# 2 -0.544021  0.149877
# 3  0.912945  0.996467
# 4 -0.916522  0.114755
# 5  0.551427 -0.404065

# %%
np.sin(df_new.val2)
# Out:
# 0   -0.846220
# 1   -0.558789
# 2    0.149877
# 3    0.996467
# 4    0.114755
# 5   -0.404065
# Name: val2, dtype: float64

# %% [markdown]
# Apply()

# %%
df
# Out:
#   Group  val1  val2
# 0     x     2    23
# 1     y     5    54
# 2     z    10    19
# 3     x    20   209
# 4     y    42   424
# 5     z    32   324

# %%
df.apply(np.sum)
# Out:
# Group    xyzxyz
# val1        111
# val2       1053
# dtype: object

# %%
dff=df.loc[:,"val1":"val2"]
dff
# Out:
#    val1  val2
# 0     2    23
# 1     5    54
# 2    10    19
# 3    20   209
# 4    42   424
# 5    32   324

# %%
dff.apply(np.mean)
# Out:
# val1     18.5
# val2    175.5
# dtype: float64

# %%
dff.apply(np.mean,axis=1)
# Out:
# 0     12.5
# 1     29.5
# 2     14.5
# 3    114.5
# 4    233.0
# 5    178.0
# dtype: float64

# %%
df.groupby("Group").apply(np.mean)
# Out:
# Group
# x     63.50
# y    131.25
# z     96.25
# dtype: float64

# %%
def cube(x):
    return x**3

# %%
df.val1.apply(cube)
# Out:
# 0        8
# 1      125
# 2     1000
# 3     8000
# 4    74088
# 5    32768
# Name: val1, dtype: int64

# %%
len(df)
# Out:
# 6

# %% [markdown]
# Examining dataset 3

# %%
df=sns.load_dataset("titanic")
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.displot(df["age"]);

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %% [markdown]
# Povit Table

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.groupby("sex")[["survived"]].mean()
# Out:
#         survived
# sex
# female  0.742038
# male    0.188908

# %%
df.groupby(["sex","embark_town"])[["survived"]].mean()
# Out:
#                     survived
# sex    embark_town
# female Cherbourg    0.876712
#        Queenstown   0.750000
#        Southampton  0.689655
# male   Cherbourg    0.305263
#        Queenstown   0.073171
#        Southampton  0.174603

# %%
df.groupby(["sex","embark_town"])[["survived"]].mean().unstack()
# Out:
#              survived
# embark_town Cherbourg Queenstown Southampton
# sex
# female       0.876712   0.750000    0.689655
# male         0.305263   0.073171    0.174603

# %%
df.pivot_table("survived",index="sex",columns="embark_town")
# Out:
# embark_town  Cherbourg  Queenstown  Southampton
# sex
# female        0.876712    0.750000     0.689655
# male          0.305263    0.073171     0.174603

# %%
df.pivot_table("survived",index="sex",columns="embark_town",aggfunc=["sum","mean","std"])
# Out:
#                   sum                             mean                         \
# embark_town Cherbourg Queenstown Southampton Cherbourg Queenstown Southampton
# sex
# female             64         27         140  0.876712   0.750000    0.689655
# male               29          3          77  0.305263   0.073171    0.174603
#
#                   std
# embark_town Cherbourg Queenstown Southampton
# sex
# female       0.331042   0.439155    0.463778
# male         0.462962   0.263652    0.380058

# %%
df.pivot_table("survived",index=["sex","class"],columns="embark_town",aggfunc=["sum","mean","std"])
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_16072\482252922.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   df.pivot_table("survived",index=["sex","class"],columns="embark_town",aggfunc=["sum","mean","std"])
# C:\Users\Dell\AppData\Local\Temp\ipykernel_16072\482252922.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   df.pivot_table("survived",index=["sex","class"],columns="embark_town",aggfunc=["sum","mean","std"])
# ...
